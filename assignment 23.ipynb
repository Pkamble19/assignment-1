# %% [markdown]
# # Q1. If you have any, what are your choices for increasing the comparison between different figures on the same graph?
#
# There are several choices for increasing the comparison between different figures on the same graph:
#
# Using different colors for different figures.
# Using different types of lines (solid, dashed, dotted) for different figures.
# Using markers (dots, squares, triangles) to highlight data points.
# Using annotations or labels to provide additional information about the data.
#
# # Q2. Can you explain the benefit of compound interest over a higher rate of interest that does not compound after reading this chapter?
#
# Compound interest refers to the practice of earning interest on both the principal amount and the accumulated interest of an investment. The benefit of compound interest over a higher rate of interest that does not compound is that it allows the investment to grow at a faster rate over time. As the investment grows, the amount of interest earned also grows, which in turn leads to even greater growth in the investment. Over a long period of time, compound interest can result in significantly higher returns compared to a higher rate of interest that does not compound.
#
# # Q3. What is a histogram, exactly? Name a numpy method for creating such a graph.
#
# A histogram is a graphical representation of the distribution of a dataset. It consists of a series of rectangles (bins) that represent the frequency or count of values within a certain range or interval. The height of each rectangle represents the count or frequency of values within the bin.
#
# A numpy method for creating a histogram is numpy.histogram(). This function takes an array of data and returns the counts and bin edges for the histogram.
#
# # Q4. If necessary, how do you change the aspect ratios between the X and Y axes?
#
# To change the aspect ratio between the X and Y axes, you can use the plt.axis() function in Matplotlib. By default, the aspect ratio is set to "equal", which means that one unit on the X axis is equal to one unit on the Y axis. To change the aspect ratio, you can set the aspect parameter to a value other than "equal". For example, to set the aspect ratio to 2:1, you can use the following code:
#
# # import matplotlib.pyplot as plt
#
# # plt.plot(x, y)
# # plt.axis('scaled')
# # plt.axis('equal')
# # plt.axis('equal', adjustable='box')
# # plt.axis('equal', adjustable='datalim')
#
#
# # Q5. Compare and contrast the three types of array multiplication between two numpy arrays: dot product, outer product, and regular multiplication of two numpy arrays.
#
# The three types of array multiplication between two numpy arrays are dot product, outer product, and regular multiplication.
#
# Dot product:
#
# Computes the sum of the element-wise products of two arrays.
# The resulting array has the same number of dimensions as the input arrays.
# Useful for matrix multiplication and other linear algebra operations.
# Can be computed using numpy.dot() or the @ operator in Python 3.5+.
# Outer product:
#
# Computes the element-wise products of two arrays and returns the result as a new array.
# The resulting array has a higher number of dimensions than the input arrays.
# Useful for computing the product of two vectors to obtain a matrix.
# Can be computed using numpy.outer().
# Regular multiplication:
#
# Computes the element-wise products of two arrays and returns the result as a new array.
# The resulting array has the same number of dimensions as the input arrays.
# Useful for computing point-wise products of arrays or broadcasting operations.
# Can be computed using numpy.multiply() or the * operator in Python.
#
# # Q6. Before you buy a home, which numpy function will you use to measure your monthly mortgage payment?
#
# To calculate the monthly mortgage payment, we can use the numpy function "pmt". The pmt function takes three arguments: the interest rate, the number of periods, and the present value (i.e., the loan amount). For example, to calculate the monthly mortgage payment for a 30-year loan of $200,000 with an annual interest rate of 5, we can use the following code
#
# import numpy as np
#
# interest_rate = 0.05 / 12
# num_periods = 30 * 12
# present_value = 200000
#
# monthly_payment = np.pmt(interest_rate, num_periods, present_value)
# print(monthly_payment)
# The output will be -1073.64, which means that the monthly mortgage payment is $1,073.64.
#
# # Q7. Can string data be stored in a numpy array?
#
# Yes, numpy arrays can store string data. In fact, numpy arrays can store data of any type, including strings, integers, floats, and objects. To create a numpy array of strings, we can use the "numpy.array" function and pass a list of strings as an argument. For example, to create a numpy array of three strings, we can use the following code:
#
# import numpy as np
#
# strings = np.array(['apple', 'banana', 'cherry'])
# print(strings)
# The output will be:
# array(['apple', 'banana', 'cherry'], dtype='<U6')
# Here, the "dtype='<U6'" means that the array is of type unicode string and can store strings of up to 6 characters long. If we want to store longer strings, we can increase the length by changing the number after the 'U'. For example, dtype='<U10' will allow strings of up to 10 characters long.
